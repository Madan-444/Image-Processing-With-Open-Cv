# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('../Open cv Tuts/dogs.jpg')

# %%
type(img)
img.shape
# Out:
# (600, 600, 3)

# %%
#img = cv2.imread('worng/path/jdls.jpg')

# %%
#type(img)

# %%
img.shape
plt.imshow(img)

# %%
#Matplot-RGB
#OpenCv -BRG

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../Open cv Tuts/dogs.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
flifed = cv2.flip(img_gray,1)
plt.imshow(flifed)

# %%
my_img = cv2.imread('../Open cv Tuts/madan.jpg',cv2.IMREAD_GRAYSCALE)
type(my_img)
fix_img = cv2.cvtColor(my_img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img,cmap='gray')

# %%
ulto = cv2.flip(my_img,-1)
plt.imshow(ulto)
cv2.imwrite('totallynew_grayscale.jpg',fix_img)
# Out:
# True
